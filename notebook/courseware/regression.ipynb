# %% [markdown]
# # metrics
#
# ## Explained_variance_score

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(['dark_background'])
# %matplotlib inline

# %%
# Explained_variance_score
from sklearn.metrics import explained_variance_score

y_true = [3, -0.5, 2, 7] # ground truth
y_pred = [2.5, 0.0, 2, 8] # prediction
print('explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred)))

y_true = [[0.5, 1], [-1, 1], [7, -6]]
y_pred = [[0, 2], [-1, 2], [8, -5]]
print('explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred, multioutput='raw_values')))
print('explained_variance_score: {}'.format(explained_variance_score(y_true, y_pred, multioutput=[0.3, 0.7])))
# Out:
# explained_variance_score: 0.9571734475374732
# explained_variance_score: [0.96774194 1.        ]
# explained_variance_score: 0.9903225806451612

# %% [markdown]
# ## Mean absolute error

# %%
# Mean absolute error
from sklearn.metrics import mean_absolute_error

y_true = [3, -0.5, 2, 7] # ground truth
y_pred = [2.5, 0.0, 2, 8] # prediction
print('mean_absolute_error: {}'.format(mean_absolute_error(y_true, y_pred)))

y_true = [[0.5, 1], [-1, 1], [7, -6]]
y_pred = [[0, 2], [-1, 2], [8, -5]]
print('mean_absolute_error: {}'.format(mean_absolute_error(y_true, y_pred)))
print('mean_absolute_error: {}'.format(mean_absolute_error(y_true, y_pred, multioutput='raw_values')))
print('mean_absolute_error: {}'.format(mean_absolute_error(y_true, y_pred, multioutput=[0.3, 0.7])))
# Out:
# mean_absolute_error: 0.5
# mean_absolute_error: 0.75
# mean_absolute_error: [0.5 1. ]
# mean_absolute_error: 0.85

# %% [markdown]
# ## Mean squared error

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error

y_true = [3, -0.5, 2, 7] # ground truth
y_pred = [2.5, 0.0, 2, 8] # prediction
print('mean_squared_error: {}'.format(mean_squared_error(y_true, y_pred)))

y_true = [[0.5, 1], [-1, 1], [7, -6]]
y_pred = [[0, 2], [-1, 2], [8, -5]]
print('mean_squared_error: {}'.format(mean_squared_error(y_true, y_pred)))
# Out:
# mean_squared_error: 0.375
# mean_squared_error: 0.7083333333333334

# %% [markdown]
# ## Mean squared logarithmic error

# %%
# Mean squared logarithmic error
from sklearn.metrics import mean_squared_log_error

y_true = [3, 5, 2.5, 7] # ground truth
y_pred = [2.5, 5, 4, 8] # prediction
print('mean_squared_log_error: {}'.format(mean_squared_log_error(y_true, y_pred)))

y_true = [[0.5, 1], [1, 2], [7, 6]]
y_pred = [[0.5, 2], [1, 2.5], [8, 8]]
print('mean_squared_log_error: {}'.format(mean_squared_log_error(y_true, y_pred)))
# Out:
# mean_squared_log_error: 0.03973012298459379
# mean_squared_log_error: 0.044199361889160536

# %% [markdown]
# ## Median absolute error

# %%
# Median absolute error
from sklearn.metrics import median_absolute_error

y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
print('median_absolute_error: {}'.format(median_absolute_error(y_true, y_pred)))
# Out:
# median_absolute_error: 0.5

# %%
# R² score
from sklearn.metrics import r2_score

y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
print(r2_score(y_true, y_pred)) 

y_true = [[0.5, 1], [-1, 1], [7, -6]]
y_pred = [[0, 2], [-1, 2], [8, -5]]
print(r2_score(y_true, y_pred, multioutput='variance_weighted'))
print(r2_score(y_true, y_pred, multioutput='uniform_average'))
print(r2_score(y_true, y_pred, multioutput='raw_values'))
print(r2_score(y_true, y_pred, multioutput=[0.3, 0.7]))
# Out:
# 0.9486081370449679
# 0.9382566585956417
# 0.9368005266622779
# [0.96543779 0.90816327]
# 0.9253456221198156

# %% [markdown]
# # Regreesion algorithms
#
# ## KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

X = np.linspace(0, 100, 100).reshape(-1, 1)
y = np.zeros(X.shape)
y[50:, 0] = 1

reg_knn = KNeighborsRegressor(n_neighbors=2)
reg_knn.fit(X, y)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#           weights='uniform')

# %%
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.scatter(X, y)
plt.title('Row Data')

plt.subplot(122)
plt.scatter(X, y)
k = 1
for i in range(k):
    test_sample = np.random.uniform(X[49], X[50])
    plt.scatter(test_sample, reg_knn.predict([test_sample]))
plt.title('Regression KNN')
# Out:
# Text(0.5, 1.0, 'Regression KNN')

# %% [markdown]
# ## Radius-KNN

# %%
from sklearn.neighbors import RadiusNeighborsRegressor

reg_knn_radius = RadiusNeighborsRegressor(radius=1.0)
reg_knn_radius.fit(X, y)
# Out:
# RadiusNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#              metric_params=None, n_jobs=None, p=2, radius=1.0,
#              weights='uniform')

# %%
plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.scatter(X, y)
plt.title('Row Data')

plt.subplot(122)
plt.scatter(X, y)
k = 1
for i in range(k):
    test_sample = np.random.uniform(X[49], X[50])
    plt.scatter(test_sample, reg_knn_radius.predict([test_sample]))
plt.title('Regression Radius-KNN')
# Out:
# Text(0.5, 1.0, 'Regression Radius-KNN')

# %% [markdown]
# ## SVM

# %%
import numpy as np
from sklearn.svm import SVR

# Generate sample data
X = np.sort(5 * np.random.rand(40, 1), axis=0)
y = np.sin(X).ravel() # 1-d

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.title('Row Data')
# Out:
# Text(0.5, 1.0, 'Row Data')

# %%
# Add noise to targets
y[::5] += 3 * (0.5 - np.random.rand(8))

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.title('Data with noise')
# Out:
# Text(0.5, 1.0, 'Data with noise')

# %%
# Fit regression model
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_lin = SVR(kernel='linear', C=1e3)
svr_poly = SVR(kernel='poly', C=1e3, degree=2)
y_rbf = svr_rbf.fit(X, y).predict(X)
y_lin = svr_lin.fit(X, y).predict(X)
y_poly = svr_poly.fit(X, y).predict(X)
# Out:
# /Users/wind/WORK/code/mistywind_baby_learning/venv_baby_learning/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# Look at the results
lw = 2
plt.figure(figsize=(8, 6))
plt.scatter(X, y, color='darkorange', label='data')
plt.plot(X, y_rbf, color='navy', lw=lw, label='RBF model')
plt.plot(X, y_lin, color='c', lw=lw, label='Linear model')
plt.plot(X, y_poly, color='cornflowerblue', lw=lw, label='Polynomial model')
plt.xlabel('data')
plt.ylabel('target')
plt.title('Support Vector Regression')
plt.legend()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
# y = 1 * x_0 + 2 * x_1 + 3
y = np.dot(X, np.array([1, 2])) + 3
reg = LinearRegression().fit(X, y)
print(reg.score(X, y))
print(reg.coef_)
print(reg.intercept_) 
print(reg.predict(np.array([[3, 5]])))
# Out:
# 1.0
# [1. 2.]
# 3.0000000000000018
# [16.]
# /Users/wind/WORK/code/mistywind_baby_learning/venv_baby_learning/lib/python3.7/site-packages/sklearn/linear_model/base.py:485: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)

# %%
from mpl_toolkits.mplot3d import Axes3D

xx = np.arange(0, 10, 0.25)
yy = np.arange(0, 10, 0.25)
xx,yy = np.meshgrid(xx, yy)
z = 1 * xx + 2 * yy + 3
fig = plt.figure(figsize=(12, 6))

ax = fig.add_subplot(121, projection='3d', title='Row Data')
ax.scatter(X[:,0], X[:,1], y, s=100, c='r', marker='o')

ax = fig.add_subplot(122, projection='3d', title='Regression-LR Surface')
ax.plot_surface(xx, yy, z, color='g')

# %% [markdown]
# ## Bayesian

# %%
from sklearn.linear_model import BayesianRidge

# %%
# Generating simulated data with Gaussian noise
np.random.seed(0)
X = np.linspace(0, 10, 100)
noise = np.random.normal(0, 1, len(X))
y = np.sqrt(X) * np.sin(X) + 0.1 * noise
X.shape, y.shape
# Out:
# ((100,), (100,))

# %%
fig = plt.figure()
plt.scatter(X, y, color='gold', marker='^')
plt.title('Trainning Data')
# Out:
# Text(0.5, 1.0, 'Trainning Data')

# %%
# Fit the Bayesian Ridge Regression
reg_bayes = BayesianRidge(compute_score=True)
reg_bayes.fit(np.vander(X, 10), y)
# Out:
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, compute_score=True, copy_X=True,
#        fit_intercept=True, lambda_1=1e-06, lambda_2=1e-06, n_iter=300,
#        normalize=False, tol=0.001, verbose=False)

# %%
# testing data
X_plot = np.arange(0, 10, 0.5)
y_plot = np.sqrt(X_plot) * np.sin(X_plot)
y_predict = reg_bayes.predict(np.vander(X_plot, 10))

# %%
fig = plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title('Regression Bayesian')
plt.scatter(X, y, color='gold', marker='^', label='Train Data')
plt.plot(X_plot, y_predict, label='Bayesian Ridge')
plt.xlabel("x")
plt.ylabel("y")
plt.legend()

plt.subplot(122)
coefs = reg_bayes.coef_
plt.title("Histogram of the weights")
plt.hist(coefs, bins=len(coefs), log=True)
# Out:
# (array([1., 0., 0., 0., 5., 1., 1., 0., 1., 1.]),
#  array([-0.31847101, -0.24178796, -0.16510491, -0.08842187, -0.01173882,
#          0.06494422,  0.14162727,  0.21831032,  0.29499336,  0.37167641,
#          0.44835945]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()

# %%
fig = plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.title('Row Data')
# Out:
# Text(0.5, 1.0, 'Row Data')

# %%
y[::5] += 3 * (0.5 - rng.rand(16))

# %%
fig = plt.figure(figsize=(8, 6))
plt.scatter(X, y)
plt.title('Data with noise')
# Out:
# Text(0.5, 1.0, 'Data with noise')

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=5, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
# Predict
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# %%
# Plot the results
plt.figure(figsize=(8, 6))
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue",
         label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=1000, n_features=4, n_informative=2, 
                       random_state=0, shuffle=True)
regr = RandomForestRegressor(max_depth=5, random_state=0, n_estimators=100)
regr.fit(X[:800], y[:800])

print(regr.feature_importances_)
print(regr.score(X[800:], y[800:])) # R^2
# Out:
# [6.86763543e-04 3.58510856e-01 2.99367293e-04 6.40503013e-01]
# 0.97116348109421

# %% [markdown]
# ## GBDT

# %%
from sklearn import ensemble
from sklearn.metrics import mean_squared_error

# %%
X, y = make_regression(n_samples=1000, n_features=4, n_informative=2,
                       random_state=0, shuffle=True)
regr = ensemble.GradientBoostingRegressor()
regr.fit(X[:800], y[:800])

print(regr.feature_importances_)
print(regr.score(X[800:], y[800:])) # R^2
# Out:
# [3.93488093e-05 3.71633167e-01 1.74429608e-04 6.28153054e-01]
# 0.9941029146335633
